# %%
#We import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#We import our dataset using pandas
df=pd.read_csv("Iris.csv",index_col=False)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#In the next few steps we will look at the characteristics of our dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#Let's look the correlation of our data with the SepalWidthCm column.
correlation= df.corr()
print(correlation['SepalWidthCm'].sort_values(ascending=False))
# Out:
# SepalWidthCm     1.000000
# SepalLengthCm   -0.109369
# PetalWidthCm    -0.356544
# Id              -0.397729
# PetalLengthCm   -0.420516
# Name: SepalWidthCm, dtype: float64

# %%
#Let's look whether our data has any null values.
#We can see that our dataset has no null values.
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#lets look on the types of iris in our dataset.
data=df.Species.value_counts()

#Lets visualize the speciess in a pie chart.
import plotly.express as px

Iris_type= data.index
quantity = data.values

figure = px.pie(df, 
             values=quantity, 
             names=Iris_type,hole = 0.5, 
             title="Distribution of Species Type")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#We want to remove the id ccolumn as a characteristic of our dataset from our data frame
df.set_index('Id',inplace=True)
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
# we want to split our data for data in x and y inputs

x=df.drop("Species",axis=1)
y=df["Species"]

# %%
#splitting data into training and test sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
#Let's train the model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))
# Out:
# 0.9666666666666667

# %%
#features=[SepalLengthCm	SepalWidthCm	PetalLengthCm	PetalWidthCm]
features = np.array([[5.4,3.4,1.5,0.4]])
print(model.predict(features))
# Out:
# ['Iris-setosa']
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning:
#
# X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names

# %%
#We want to confirm whether after inputing the x values the model will correctly predict the y-values
x_test.head(), y_test.head()
# Out:
# (     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
#  Id
#  98             6.2           2.9            4.3           1.3
#  97             5.7           2.9            4.2           1.3
#  94             5.0           2.3            3.3           1.0
#  49             5.3           3.7            1.5           0.2
#  129            6.4           2.8            5.6           2.1, Id
#  98     Iris-versicolor
#  97     Iris-versicolor
#  94     Iris-versicolor
#  49         Iris-setosa
#  129     Iris-virginica
#  Name: Species, dtype: object)

# %%
# Finding the optimum number of clusters for k-means classification

x = df.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans
wcss = [] #wcss-the sum of squared distance between each point and the centroid in a cluster.

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') # Within cluster sum of squares
plt.show()

# %%
# Applying kmeans to the dataset / Creating the kmeans classifier
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
# Visualising the clusters - On the first two columns
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()
